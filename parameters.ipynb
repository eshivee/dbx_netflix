# %%
filenames = [
    {'filename':'directors'},
    {'filename':'cast'},
    {'filename':'countries'},
    {'filename':'category'}
]

# %%
dbutils.jobs.taskValues.set(key = 'filenames', value = filenames)
